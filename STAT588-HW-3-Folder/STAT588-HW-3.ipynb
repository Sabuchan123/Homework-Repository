# %% [markdown]
# **Problem 1 (Homework) **

# %% [markdown]
# $$\frac{\partial}{\partial x}f_4(x)=\frac{\partial f_4(x)}{\partial x} + \frac{\partial f_4(x)}{\partial f_3(x)}\cdot\frac{\partial f_3(x)}{\partial x}$$
# $$\frac{\partial f_4(x)}{\partial x}=-\frac{1}{(x+f_3(x))^2}=-f_4(x)^2$$
# $$\frac{\partial f_4(x)}{\partial f_3(x)}=-\frac{1}{(x+f_3(x))^2}=-f_4(x)^2$$
# $$\frac{\partial f_4(x)}{\partial x} + \frac{\partial f_4(x)}{\partial f_3(x)}\cdot\frac{\partial f_3(x)}{\partial x}=-f_4(x)^2(1+\frac{\partial f_3(x)}{\partial x})$$
# $$\frac{\partial f_3(x)}{\partial x}=\frac{\partial f_3(x)}{\partial x}+\frac{\partial f_3(x)}{\partial f_2(x)}\cdot\frac{\partial f_2(x)}{\partial x}$$
# $$\frac{\partial f_3(x)}{\partial x}=-f_3(x)^2(1+\frac{\partial f_2(x)}{\partial x})$$
# $$\frac{\partial f_2(x)}{\partial x}=\frac{\partial f_2(x)}{\partial x}+\frac{\partial f_2(x)}{\partial f_1(x)}\frac{\partial f_1(x)}{\partial x}$$
# $$\frac{\partial f_1(x)}{\partial x}=-f_1(x)^2$$
# $$\frac{\partial f_2(x)}{\partial x}=-f_2(x)^2(1-f_1(x)^2)$$
# $$\frac{\partial}{\partial x}f_4(x)=-f_4(x)^2(1+\frac{\partial f_3(x)}{\partial x})=-f_4(x)^2(1-f_3(x)^2(1-f_2(x)^2(1-f_1(x)^2)))$$

# %% [markdown]
# **Problem 2 (Homework)**

# %% [markdown]
# Let $X^n=\sigma(S^n)$, then a)
# $$\frac{\partial f}{\partial w_{1,1}^1}=\frac{\partial X^3}{\partial w_{1,1}^1}=\frac{\partial X^3}{\partial S^3} \cdot (\frac{\partial S^3}{\partial x^2_1} \cdot \frac{\partial x^2_1}{\partial s^2_1} \cdot \frac{\partial s^2_1}{\partial w_{1,1}^1} + \frac{\partial S^3}{\partial X^2} \cdot \frac{\partial X^2}{\partial S^2} \cdot \frac{\partial S^2}{\partial x^1_1} \cdot \frac{\partial x^1_1}{\partial s^1_1} \cdot \frac{\partial s^1_1}{\partial w_{1,1}^1})$$
#
# $$\frac{\partial X^3}{\partial s^3}=\frac{\partial}{\partial s^3}\sigma(s^3)=\sigma^\prime(s^3)$$
#
# $$S^3=W^3X^2+b^2=w^3_1x^2_1 + w^3_2x^2_2 + b^2$$
# $$\frac{\partial S^3}{\partial x^2_1}=w^3_1$$
# $$\frac{\partial x^2_1}{\partial s^2_1}=\frac{\partial}{\partial s^2_1}\sigma(s^2_1)=\sigma^\prime(s^2_1)$$
# $$\frac{\partial s^2_1}{\partial w_{1,1}^1}=x^1_1$$
#
# $$\frac{\partial S^3}{\partial X^2}=\begin{bmatrix} w^3_1 \ w^3_2 \end{bmatrix}=W^{3,T}$$
# $$\frac{\partial X^2}{\partial S^2}=\frac{\partial}{\partial S^2}\sigma(S^2)=\sigma^\prime(S^2)=\begin{bmatrix}\frac{\partial}{\partial s^2_1}\sigma(s^2_1) & \frac{\partial}{\partial s^2_2}\sigma(s^2_1) \\ \frac{\partial}{\partial s^2_1}\sigma(s^2_2) & \frac{\partial}{\partial s^2_2}\sigma(s^2_2)\end{bmatrix}=\begin{bmatrix}\sigma^\prime(s^2_1) & 0 \\ 0 & \sigma^\prime(s^2_2)\end{bmatrix}$$
# $$S^2=W^2X^1+b^2=\begin{bmatrix}w^1_{1,1}x^1_1 + w^1_{1,2}x^1_2 + b^2_1 \\ w^1_{2,1}x^1_1 + w^1_{2,2}x^1_2 + b^2_2\end{bmatrix}$$
# $$\frac{\partial S^2}{\partial x^1_1}=\begin{bmatrix}w^1_{1,1} \\ w^1_{2,1}\end{bmatrix}=W^{1}_1$$
# $$\frac{\partial x^1_1}{\partial s^1_1}=\frac{\partial}{\partial s^1_1}\sigma(s^1_1)=\sigma^\prime(s^1_1)$$
# $$\frac{\partial s^1_1}{\partial w^1_{1,1}}=x^0_1$$
#
# $$\frac{\partial X^3}{\partial w_{1,1}^1}=\sigma^\prime(s^3)(w^3_1\cdot\sigma^\prime(s^2_1)\cdot x^1_1+W^{3,T}\cdot\sigma^\prime(S^2)\cdot W^{1,T}_1\cdot\sigma^\prime(s^1_1)\cdot x^0_1)$$
# $$=\sigma^\prime(s^3)(w^3_1\cdot\sigma^\prime(s^2_1)\cdot x^1_1+(w^3_1w^1_{1,1}\sigma^\prime(s^2_1) + w^3_2w^1_{2,1}\sigma^\prime(s^2_2))\cdot\sigma^\prime(s^1_1)\cdot x^0_1)$$
# and b)
# $$\frac{\partial X^3}{\partial W^1}=\frac{\partial X^3}{\partial S^3}\cdot\frac{\partial S^3}{\partial X^2}\cdot\frac{\partial X^2}{\partial S^2}\cdot(\frac{\partial S^2}{\partial W^1} + \frac{\partial S^2}{\partial X^1}\cdot\frac{\partial X^1}{\partial S^1}\cdot\frac{\partial S^1}{\partial W^1})$$
# $$=\sigma^\prime(S^3)\cdot W^{3,T}\cdot\sigma^\prime(S^2)\cdot (X^1 + W^{1,T}\cdot\sigma^\prime(S^1)\cdot X^0)$$
# Dimensions are valid, running out of time to expand.

# %% [markdown]
# **Problem 3 (Homework)**

# %%
import torch
from torchvision import datasets, transforms
mnist_train = datasets.MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
mnist_test = datasets.MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())
print(mnist_train.data.shape)
print(mnist_test.data.shape)


all_data = torch.cat((mnist_train.data, mnist_test.data), dim=0).float()
all_targets = torch.cat((mnist_train.targets, mnist_test.targets), dim=0)

indices = torch.randperm(all_data.size(0))[:5000]
x = all_data[indices]
x = x.view(5000, 784)
x = (x - x.mean()) / x.std()

y = torch.full((5000, 10), -0.9, device='cuda')
y.scatter_(1, all_targets[indices].unsqueeze(1).to('cuda'), 0.9)

print(x.shape)
print(y.shape)

train_input = x[:4000].reshape(4000, -1).to('cuda')
train_target = y[:4000].to('cuda')
test_input = x[4000:].reshape(1000, -1).to('cuda')
test_target = y[4000:].to('cuda')

print("Train Input Shape:", train_input.shape)
print("Train Target Shape:", train_target.shape)
print("Test Input Shape:", test_input.shape)
print("Test Target Shape:", test_target.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])
# torch.Size([5000, 784])
# torch.Size([5000, 10])
# Train Input Shape: torch.Size([4000, 784])
# Train Target Shape: torch.Size([4000, 10])
# Test Input Shape: torch.Size([1000, 784])
# Test Target Shape: torch.Size([1000, 10])

# %%
w1 = torch.eye(784, device='cuda', dtype=torch.float32)
random_matrix = torch.normal(0, 1e-1, size=(784, 784), device='cuda', dtype=torch.float32)
w1.add_(random_matrix)
b1 = torch.normal(0, 1e-1, size=(784,1), device='cuda', dtype=torch.float32)
b2 = torch.normal(0, 1e-1, size=(784,1), device='cuda', dtype=torch.float32)
w3 = torch.normal(0, 1e-1, size=(10, 784), device='cuda', dtype=torch.float32)
b3 = torch.normal(0, 1e-1, size=(10,1), device='cuda', dtype=torch.float32)

dl_dw1 = torch.zeros_like(w1)
dl_db1 = torch.zeros_like(b1)
dl_db2 = torch.zeros_like(b2)
dl_dw3 = torch.zeros_like(w3)
dl_db3 = torch.zeros_like(b3)

def sigma(x):
    return torch.tanh(x)

def dsigma(x):
    return 1 - torch.tanh(x)**2

# test = torch.ones(5)
# print(sigma(test))
# print(dsigma(test))

def loss(v,t):
    return torch.linalg.norm(t-v)**2

def dloss(v,t):
    return 2*(v-t)

def forward_pass(w1, b1, b2, w3, b3, x):
    x0 = x.view(-1, 1) # 784 x 1
    s1 = w1 @ x0 + b1  # 784 x 1
    x1 = sigma(s1)     # 784 x 1
    s2 = w1 @ x1 + b2  # 784 x 1
    x2 = sigma(s2)     # 784 x 1
    s3 = w3 @ x2 + b3  # 10 x 1
    x3 = sigma(s3)     # 10 x 1
    return s1, x1, s2, x2, s3, x3

def backward_pass(w1, w3, t, x, s1, x1, s2, x2, s3, x3, dl_dw1, dl_db1, dl_db2, dl_dw3, dl_db3):
    x0 = x # 784 x 1
    dl_dx3 = dloss(x3, t)        # 10 x 1
    dl_ds3 = dl_dx3 * dsigma(s3) # 10 x 1 (note dsigma(s3) mathematically has a size of 10x10, but the off diagonals are all zeroes).
    dl_dx2 = w3.T @ dl_ds3       # 784 x 1 (note in the equation in problem 2, w3.T is multiplied to the right of dl_ds3, but that would work only if dl_ds3 was 10x10 and not 10x1, or if dl_ds3 was transposed)
    dl_ds2 = dl_dx2 * dsigma(s2) # 784 x 1 (note same idea applies as dl_ds3)
    dl_dx1 = w1.T @ dl_ds2       # 784 x 1 (note same as before)
    dl_ds1 = dl_dx1 * dsigma(s1) # 784 x 1 (note same as before)

    dl_dw3.add_(dl_ds3.view(-1, 1) @ x2.view(1, -1)) # 10 x 784 (note without .view, both dl_ds3 and x2 would be seen as 1d tensors)
    dl_db3.add_(dl_ds3)
    dl_dw1.add_(dl_ds2.view(-1, 1) @ x1.view(1, -1) + dl_ds1.view(-1, 1) @ x0.view(1, -1)) # 784 x 784
    dl_db2.add_(dl_ds2)
    dl_db1.add_(dl_ds1)

# %%
eta = 0.1 / train_input.size(0)
for step in range(250):
    print("Step:", step + 1)
    dl_dw1.zero_()
    dl_db1.zero_()
    dl_db2.zero_()
    dl_dw3.zero_()
    dl_db3.zero_()

    train_loss = 0.0
    train_errors = 0
    for i in range(train_input.size(0)):
        x = train_input[i].view(-1, 1)
        t = train_target[i].view(-1, 1)
        s1, x1, s2, x2, s3, x3 = forward_pass(w1, b1, b2, w3, b3, x)
        train_errors += x3.argmax().item() != t.argmax().item()
        train_loss += loss(x3, t).item()

        backward_pass(w1, w3, t, x, s1, x1, s2, x2, s3, x3, dl_dw1, dl_db1, dl_db2, dl_dw3, dl_db3)
    print("Train Loss:", train_loss)
    print("Train Errors:", train_errors / train_input.size(0))
        
    with torch.no_grad():
        w1 -= eta * dl_dw1
        b1 -= eta * dl_db1
        b2 -= eta * dl_db2
        w3 -= eta * dl_dw3
        b3 -= eta * dl_db3

    test_errors = 0
    for i in range(test_input.size(0)):
        _, _, _, _, _, x3 = forward_pass(w1, b1, b2, w3, b3, test_input[i].view(-1, 1))
        test_errors += x3.argmax().item() != test_target[i].argmax().item()
    print("Test Errors:", test_errors / test_input.size(0))
# Out:
# Step: 1
# Train Loss: 58102.09879595041
# Train Errors: 0.8975
# Test Errors: 0.751
# Step: 2
# Train Loss: 14800.30740326643
# Train Errors: 0.75425
# Test Errors: 0.743
# Step: 3
# Train Loss: 14786.699331499636
# Train Errors: 0.74725
# Test Errors: 0.737
# Step: 4
# Train Loss: 14774.918778777122
# Train Errors: 0.7435
# Test Errors: 0.734
# Step: 5
# Train Loss: 14762.682555831969
# Train Errors: 0.73825
# Test Errors: 0.73
# Step: 6
# Train Loss: 14748.210971958935
# Train Errors: 0.73575
# Test Errors: 0.723
# Step: 7
# Train Loss: 14728.594906114042
# Train Errors: 0.73125
# Test Errors: 0.722
# Step: 8
# Train Loss: 14696.09577421099
# Train Errors: 0.72075
# Test Errors: 0.713
# Step: 9
# Train Loss: 14646.617804765701
# Train Errors: 0.714
# Test Errors: 0.706
# Step: 10
# Train Loss: 14521.427498623729
# Train Errors: 0.70075
# Test Errors: 0.701
# Step: 11
# Train Loss: 14174.813553526998
# Train Errors: 0.68975
# Test Errors: 0.69
# Step: 12
# ...

# %% [markdown]
# With step size of 0.01 over the size of the training set, after 200 iterations, a total loss of 3262.416 was achieved with a train error of 0.14225 and test error of 0.217.
#
# With step size of 0.005 over the size of the training set, after 250 iterations, a total loss of 3848.13 was achieved with a train error of 0.16 and test error of 0.22.
#
# With step size of 0.1 over the size of the training set, after 250 iterations, a total loss of 4935.728 was achieved with a train error of 0.3135 and test error of 0.363.
